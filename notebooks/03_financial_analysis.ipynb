# %% [markdown]
# # 03 — Financial Analysis
#
# Review ROI and key findings from `outputs/` (executive_summary.md, key_findings.csv, financial_analysis_results).

# %%
import pandas as pd
from pathlib import Path
ROOT = Path('.').resolve()
if not (ROOT / 'outputs').exists(): ROOT = ROOT.parent
kf = pd.read_csv(ROOT / 'outputs' / 'key_findings.csv')
kf

# %%
# ROI and savings scenarios (if CSV exists)
import os
roi_path = ROOT / 'outputs' / 'roi_analysis.csv'
if roi_path.exists():
    pd.read_csv(roi_path).head(10)
